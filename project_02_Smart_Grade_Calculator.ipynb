# %%
print("----SWMART GRADE CALCULATOR----")
name = input("Enter Student Name: ")
sub1 = float(input("Enter Marks of Subject 1: "))
sub2 = float(input("Enter Marks of  Subject 2: "))
sub3 = float(input("Enter Marks of Subject 3: "))
sub4 = float(input("Enter Marks of Subject 4: "))
sub5 = float(input("Enter Marks of Subject 5: "))
total = sub1 + sub2 + sub3 + sub4 + sub5
average =total/5
if average >= 90:
    grade = "A+"
elif average >= 80:
    grade = "A"
elif average >= 70:
    grade = "B"
elif average >= 60:
    grade = "C"
elif average >= 50:
    grade = "D"
else:
    grade = "F"


print("\n----Result----")
print("Student Name:", name)
print("Total Marks:" , total)
print("Average Marks:" , average)
print("Grade:" , grade)
# Out:
# ----SWMART GRADE CALCULATOR----
# Enter Student Name: soumili das
# Enter Marks of Subject 1: 67
# Enter Marks of  Subject 2: 89
# Enter Marks of Subject 3: 90
# Enter Marks of Subject 4: 56
# Enter Marks of Subject 5: 78
#
# ----Result----
# Student Name: soumili das
# Total Marks: 380.0
# Average Marks: 76.0
# Grade: B
